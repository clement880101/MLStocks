# %% [markdown]
# #Setup

# %%
pip install keras-adabound
# Out:
# Requirement already satisfied: keras-adabound in /usr/local/lib/python3.6/dist-packages (0.6.0)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.6/dist-packages (from keras-adabound) (2.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from keras-adabound) (1.18.5)
# Requirement already satisfied: Keras in /usr/local/lib/python3.6/dist-packages (from keras-adabound) (2.4.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras->keras-adabound) (3.13)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from Keras->keras-adabound) (1.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras->keras-adabound) (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->Keras->keras-adabound) (1.15.0)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
#from keras_adabound import AdaBound
from tensorflow.keras import Sequential
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU
from sklearn.metrics import mean_squared_error as calc_mse
import time

# %%
csv = pd.read_csv('https://raw.githubusercontent.com/clement880101/MLStocks/master/Combined_Stock_Data_MSFT.csv', date_parser= True)
csv.columns
# Out:
# Index(['date', 'Msft_open', 'Msft_high', 'Msft_low', 'Msft_close',
#        'Msft_adjusted_close', 'Msft_volume', 'Msft_dividend',
#        'Msft_split_coefficent', 'Msft_Real Middle Band',
#        ...
#        'Amzn_ADX', 'Amzn_SMA', 'SPY_open', 'SPY_high', 'SPY_low', 'SPY_close',
#        'SPY_adjusted_close', 'SPY_volume', 'SPY_dividend',
#        'SPY_split_coefficent'],
#       dtype='object', length=114)

# %% [markdown]
# # Recurrent LSTM Neural Network

# %% [markdown]
# ###help functions

# %%
#helper functions
def to_dataframe(csv):
    # returns dataframe
    df = pd.read_csv(csv, date_parser=True)
    return df

def reverse_order(df):
    # reverse order of data so earliest day is day 0
    reversed_df = df[::-1].reset_index(drop=True)
    return reversed_df

def remove_dates(df):
  #stores dates in a dictionary
  dates = {}
  for i in range(df.shape[0]):
    date = df.iloc[i]['date']
    dates[date] = i

  df = df.drop(['date'],axis=1)

  return dates, df

def scale_data(df, target_column):
    # scale data
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(df)

    # save this value to convert stock prediction to nominal data
    upscale_value = 1 / scaler.scale_[target_column]
    return scaled_data, scaler, upscale_value

def split_data(df, date_value):
  df_before = df[df['date'] < date_value].copy()
  df_after = df[df['date'] >= date_value].copy()
  return df_before, df_after

def create_xy(data, scope, target_column):
  x = []
  y = []
  for i in range(scope, data.shape[0]):
    # the xTest will have an array of the last x "scope" days of data
    # yTest will be the the opening value of the next day
    x.append(data[i-scope:i])
    y.append(data[i,target_column])
  
  #the length of x is the data length - scope 
  #in each x there is a batch size of x "scope" points
  return np.array(x), np.array(y)
#recurrent neural network

class Rnn:
    # set values for Rnn object
    def __init__(self, rows_size, columns_size):
        self.rows = rows_size
        self.columns = columns_size
        self.model = None
        self.logs = None


    # train function for Rnn class
    def structure(self, layers, units_for_layers, dropouts_for_layers):
        #initilize Sequential rnn
        self.model = Sequential()
        # add first layer and define input shape
        self.model.add(LSTM(units_for_layers[0], activation = 'relu', return_sequences = True, input_shape = (self.rows, self.columns)))
        self.model.add(Dropout(dropouts_for_layers[0]))
        # for adding additional layers
        if layers > 2:
            for i in range(1,layers):

                return_setting = True
                #dont need to return values upstream on last layer
                if i == layers - 1: return_setting = False

                self.model.add(LSTM(units_for_layers[i], activation = 'relu', return_sequences = return_setting))
                self.model.add(Dropout(dropouts_for_layers[i]))


        #final endpoint for rnn layers
        self.model.add(Dense(units = 1))
        return None

    def summary(self):
        return self.model.summary()
      
    def history(self):
      return self.model.history

    def train(self, xTrain, yTrain, epochs, batch_size, optimizer, file_name, ada_low_lr = None, ada_high_lr = None):
        #compiles model that was created
        if optimizer != 'adaboost':
            self.model.compile(optimizer=optimizer, loss = 'mean_squared_error')
        else:
            self.model.compile(optimizer= AdaBound(lr=ada_low_lr, final_lr=ada_high_lr), loss = 'mean_squared_error')

        #create log for getting stats
        CSV_logger = CSVLogger(file_name + '.csv',separator=',',append=False)
        #fit model to data
        self.model.fit(xTrain, yTrain, epochs=epochs, batch_size=batch_size, callbacks=[CSV_logger])
        self.logs = CSV_logger
        return None

    def predict(self, input_data):
        y_hat = self.model.predict(input_data)
        return y_hat

# %%
def create_file_name(array):
  string = 'Stats'
  for item in array:
    string = string + '_' + str(item)
  return string

# %% [markdown]
# ###main

# %%
#arrange df and split by date
df = reverse_order(csv)
training_data, test_data = split_data(df, '2018-01-01')

#store date labels and drop columns 
dates_train, training_data = remove_dates(training_data)
dates_test, test_data = remove_dates(test_data)

target_column = 5 #this is MSFT adjusted column
#scale_data on training data and get scaler with value
training_data, scaler, upscale_value = scale_data(training_data, target_column-1)
test_data = scaler.transform(test_data)

# %%
#create xTrain,yTrain.. and xTest,yTest
#each x in xTrain will be an array of x days
xTrain, yTrain = create_xy(training_data, 5, target_column-1)
xTest, yTest = create_xy(test_data, 5, target_column-1)

# %% [markdown]
# ###Params loop

# %%
#batch dimensions
row_size = xTrain.shape[1]
column_size = xTrain.shape[2]
# params to test
layers = [3,5]
epochs = [10, 25, 50]
batches = [100, 200]
optimizer = 'adam'

# %%
params = []
csv_name = 'MSFT_CSD'

for l in layers:
  units = []
  dropouts = []
  for i in range(l):
    units.append(column_size)
    if i == 0:
      dropouts.append(0.2)
    else: 
      dropouts.append(0.5)

  for e in epochs:
    for b in batches:
      file_name = create_file_name([csv_name,l,e,b])
      params.append({'layers': l,'epochs': e,'batches': b, 'units': units, 'dropouts': dropouts, 'optimizer': optimizer, 'file_name': file_name})

# %%
params[0]['file_name']
# Out:
# 'Stats_MSFT_CSD_3_10_100'

# %% [markdown]
# ### Create evaluation loop

# %%
#track_time_to_train
time_training = []
networks = []
for param in params:
  t0 = time.clock()
  #Steps for rnn:
  #1. initialize, #2. structure, #train, #summary, #predict
  print('Starting this param'), print(param)
  nnet = Rnn(row_size,column_size)
  nnet.structure(param['layers'], param['units'], param['dropouts'])
  nnet.train(xTrain, yTrain, param['epochs'],param['batches'],param['optimizer'],param['file_name'])
  networks.append(nnet)
  t1 = time.clock()
  time_training.append(t1-t0)
# Out:
# Starting this param
# {'layers': 3, 'epochs': 10, 'batches': 100, 'units': [113, 113, 113], 'dropouts': [0.2, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_3_10_100'}
# Epoch 1/10
# 14/14 [==============================] - 1s 44ms/step - loss: 0.0650
# Epoch 2/10
# 14/14 [==============================] - 1s 39ms/step - loss: 0.0165
# Epoch 3/10
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0116
# Epoch 4/10
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0085
# Epoch 5/10
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0067
# Epoch 6/10
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0064
# Epoch 7/10
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0065
# Epoch 8/10
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0060
# Epoch 9/10
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0060
# Epoch 10/10
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0056
# Starting this param
# {'layers': 3, 'epochs': 10, 'batches': 200, 'units': [113, 113, 113], 'dropouts': [0.2, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_3_10_200'}
# Epoch 1/10
# 7/7 [==============================] - 0s 66ms/step - loss: 0.1254
# Epoch 2/10
# 7/7 [==============================] - 0s 63ms/step - loss: 0.0372
# Epoch 3/10
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0230
# Epoch 4/10
# 7/7 [==============================] - 0s 63ms/step - loss: 0.0133
# Epoch 5/10
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0124
# Epoch 6/10
# 7/7 [==============================] - 0s 61ms/step - loss: 0.0115
# Epoch 7/10
# 7/7 [==============================] - 0s 66ms/step - loss: 0.0090
# Epoch 8/10
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0090
# Epoch 9/10
# 7/7 [==============================] - 0s 62ms/step - loss: 0.0085
# Epoch 10/10
# 7/7 [==============================] - 0s 66ms/step - loss: 0.0084
# Starting this param
# {'layers': 3, 'epochs': 25, 'batches': 100, 'units': [113, 113, 113], 'dropouts': [0.2, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_3_25_100'}
# Epoch 1/25
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0549
# Epoch 2/25
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0148
# Epoch 3/25
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0094
# Epoch 4/25
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0078
# Epoch 5/25
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0065
# Epoch 6/25
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0063
# Epoch 7/25
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0058
# Epoch 8/25
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0053
# Epoch 9/25
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0051
# Epoch 10/25
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0052
# Epoch 11/25
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0058
# Epoch 12/25
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0045
# Epoch 13/25
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0050
# Epoch 14/25
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0052
# Epoch 15/25
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0044
# Epoch 16/25
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0040
# Epoch 17/25
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0044
# Epoch 18/25
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0042
# Epoch 19/25
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0040
# Epoch 20/25
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0037
# Epoch 21/25
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0037
# Epoch 22/25
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0039
# Epoch 23/25
# 14/14 [==============================] - 1s 45ms/step - loss: 0.0038
# Epoch 24/25
# 14/14 [==============================] - 1s 44ms/step - loss: 0.0037
# Epoch 25/25
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0034
# Starting this param
# {'layers': 3, 'epochs': 25, 'batches': 200, 'units': [113, 113, 113], 'dropouts': [0.2, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_3_25_200'}
# Epoch 1/25
# 7/7 [==============================] - 0s 68ms/step - loss: 0.1000
# Epoch 2/25
# 7/7 [==============================] - 0s 68ms/step - loss: 0.0293
# Epoch 3/25
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0168
# Epoch 4/25
# 7/7 [==============================] - 0s 68ms/step - loss: 0.0111
# Epoch 5/25
# 7/7 [==============================] - 0s 66ms/step - loss: 0.0107
# Epoch 6/25
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0086
# Epoch 7/25
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0077
# Epoch 8/25
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0075
# Epoch 9/25
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0067
# Epoch 10/25
# 7/7 [==============================] - 0s 66ms/step - loss: 0.0064
# Epoch 11/25
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0066
# Epoch 12/25
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0063
# Epoch 13/25
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0051
# Epoch 14/25
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0058
# Epoch 15/25
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0053
# Epoch 16/25
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0054
# Epoch 17/25
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0052
# Epoch 18/25
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0053
# Epoch 19/25
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0058
# Epoch 20/25
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0056
# Epoch 21/25
# 7/7 [==============================] - 0s 66ms/step - loss: 0.0058
# Epoch 22/25
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0051
# Epoch 23/25
# 7/7 [==============================] - 0s 66ms/step - loss: 0.0047
# Epoch 24/25
# 7/7 [==============================] - 0s 66ms/step - loss: 0.0044
# Epoch 25/25
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0049
# Starting this param
# {'layers': 3, 'epochs': 50, 'batches': 100, 'units': [113, 113, 113], 'dropouts': [0.2, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_3_50_100'}
# Epoch 1/50
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0647
# Epoch 2/50
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0137
# Epoch 3/50
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0091
# Epoch 4/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0073
# Epoch 5/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0058
# Epoch 6/50
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0054
# Epoch 7/50
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0055
# Epoch 8/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0054
# Epoch 9/50
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0054
# Epoch 10/50
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0045
# Epoch 11/50
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0050
# Epoch 12/50
# 14/14 [==============================] - 1s 44ms/step - loss: 0.0050
# Epoch 13/50
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0044
# Epoch 14/50
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0045
# Epoch 15/50
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0043
# Epoch 16/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0041
# Epoch 17/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0040
# Epoch 18/50
# 14/14 [==============================] - 1s 44ms/step - loss: 0.0038
# Epoch 19/50
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0040
# Epoch 20/50
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0037
# Epoch 21/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0039
# Epoch 22/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0037
# Epoch 23/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0043
# Epoch 24/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0042
# Epoch 25/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0036
# Epoch 26/50
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0034
# Epoch 27/50
# 14/14 [==============================] - 1s 44ms/step - loss: 0.0035
# Epoch 28/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0032
# Epoch 29/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0035
# Epoch 30/50
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0032
# Epoch 31/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0035
# Epoch 32/50
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0038
# Epoch 33/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0044
# Epoch 34/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0032
# Epoch 35/50
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0034
# Epoch 36/50
# 14/14 [==============================] - 1s 45ms/step - loss: 0.0031
# Epoch 37/50
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0031
# Epoch 38/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0033
# Epoch 39/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0031
# Epoch 40/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0033
# Epoch 41/50
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0028
# Epoch 42/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0027
# Epoch 43/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0028
# Epoch 44/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0028
# Epoch 45/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0033
# Epoch 46/50
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0031
# Epoch 47/50
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0027
# Epoch 48/50
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0031
# Epoch 49/50
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0027
# Epoch 50/50
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0027
# Starting this param
# {'layers': 3, 'epochs': 50, 'batches': 200, 'units': [113, 113, 113], 'dropouts': [0.2, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_3_50_200'}
# Epoch 1/50
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0962
# Epoch 2/50
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0294
# Epoch 3/50
# 7/7 [==============================] - 0s 66ms/step - loss: 0.0201
# Epoch 4/50
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0150
# Epoch 5/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0107
# Epoch 6/50
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0097
# Epoch 7/50
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0080
# Epoch 8/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0080
# Epoch 9/50
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0071
# Epoch 10/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0063
# Epoch 11/50
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0059
# Epoch 12/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0065
# Epoch 13/50
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0057
# Epoch 14/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0057
# Epoch 15/50
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0054
# Epoch 16/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0049
# Epoch 17/50
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0053
# Epoch 18/50
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0051
# Epoch 19/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0054
# Epoch 20/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0048
# Epoch 21/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0051
# Epoch 22/50
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0046
# Epoch 23/50
# 7/7 [==============================] - 0s 66ms/step - loss: 0.0050
# Epoch 24/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0045
# Epoch 25/50
# 7/7 [==============================] - 0s 63ms/step - loss: 0.0047
# Epoch 26/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0044
# Epoch 27/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0048
# Epoch 28/50
# 7/7 [==============================] - 0s 66ms/step - loss: 0.0048
# Epoch 29/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0047
# Epoch 30/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0054
# Epoch 31/50
# 7/7 [==============================] - 0s 66ms/step - loss: 0.0046
# Epoch 32/50
# 7/7 [==============================] - 0s 66ms/step - loss: 0.0044
# Epoch 33/50
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0045
# Epoch 34/50
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0049
# Epoch 35/50
# 7/7 [==============================] - 0s 63ms/step - loss: 0.0042
# Epoch 36/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0038
# Epoch 37/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0038
# Epoch 38/50
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0043
# Epoch 39/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0038
# Epoch 40/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0035
# Epoch 41/50
# 7/7 [==============================] - 0s 70ms/step - loss: 0.0040
# Epoch 42/50
# 7/7 [==============================] - 0s 63ms/step - loss: 0.0039
# Epoch 43/50
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0042
# Epoch 44/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0040
# Epoch 45/50
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0042
# Epoch 46/50
# 7/7 [==============================] - 0s 66ms/step - loss: 0.0037
# Epoch 47/50
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0034
# Epoch 48/50
# 7/7 [==============================] - 0s 63ms/step - loss: 0.0038
# Epoch 49/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0038
# Epoch 50/50
# 7/7 [==============================] - 0s 63ms/step - loss: 0.0038
# Starting this param
# {'layers': 5, 'epochs': 10, 'batches': 100, 'units': [113, 113, 113, 113, 113], 'dropouts': [0.2, 0.5, 0.5, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_5_10_100'}
# Epoch 1/10
# 14/14 [==============================] - 1s 71ms/step - loss: 0.1044
# Epoch 2/10
# 14/14 [==============================] - 1s 70ms/step - loss: 0.0351
# Epoch 3/10
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0162
# Epoch 4/10
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0115
# Epoch 5/10
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0095
# Epoch 6/10
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0079
# Epoch 7/10
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0095
# Epoch 8/10
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0073
# Epoch 9/10
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0076
# Epoch 10/10
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0063
# Starting this param
# {'layers': 5, 'epochs': 10, 'batches': 200, 'units': [113, 113, 113, 113, 113], 'dropouts': [0.2, 0.5, 0.5, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_5_10_200'}
# Epoch 1/10
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1492
# Epoch 2/10
# 7/7 [==============================] - 1s 108ms/step - loss: 0.0474
# Epoch 3/10
# 7/7 [==============================] - 1s 109ms/step - loss: 0.0414
# Epoch 4/10
# 7/7 [==============================] - 1s 109ms/step - loss: 0.0266
# Epoch 5/10
# 7/7 [==============================] - 1s 107ms/step - loss: 0.0188
# Epoch 6/10
# 7/7 [==============================] - 1s 109ms/step - loss: 0.0137
# Epoch 7/10
# 7/7 [==============================] - 1s 106ms/step - loss: 0.0122
# Epoch 8/10
# 7/7 [==============================] - 1s 108ms/step - loss: 0.0106
# Epoch 9/10
# 7/7 [==============================] - 1s 107ms/step - loss: 0.0103
# Epoch 10/10
# 7/7 [==============================] - 1s 109ms/step - loss: 0.0082
# Starting this param
# {'layers': 5, 'epochs': 25, 'batches': 100, 'units': [113, 113, 113, 113, 113], 'dropouts': [0.2, 0.5, 0.5, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_5_25_100'}
# Epoch 1/25
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0933
# Epoch 2/25
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0252
# Epoch 3/25
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0129
# Epoch 4/25
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0100
# Epoch 5/25
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0089
# Epoch 6/25
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0081
# Epoch 7/25
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0076
# Epoch 8/25
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0063
# Epoch 9/25
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0065
# Epoch 10/25
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0061
# Epoch 11/25
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0059
# Epoch 12/25
# 14/14 [==============================] - 1s 75ms/step - loss: 0.0055
# Epoch 13/25
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0054
# Epoch 14/25
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0055
# Epoch 15/25
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0065
# Epoch 16/25
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0052
# Epoch 17/25
# 14/14 [==============================] - 1s 70ms/step - loss: 0.0050
# Epoch 18/25
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0051
# Epoch 19/25
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0044
# Epoch 20/25
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0042
# Epoch 21/25
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0041
# Epoch 22/25
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0046
# Epoch 23/25
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0051
# Epoch 24/25
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0045
# Epoch 25/25
# 14/14 [==============================] - 1s 70ms/step - loss: 0.0038
# Starting this param
# {'layers': 5, 'epochs': 25, 'batches': 200, 'units': [113, 113, 113, 113, 113], 'dropouts': [0.2, 0.5, 0.5, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_5_25_200'}
# Epoch 1/25
# 7/7 [==============================] - 1s 105ms/step - loss: 0.1511
# Epoch 2/25
# 7/7 [==============================] - 1s 107ms/step - loss: 0.0411
# Epoch 3/25
# 7/7 [==============================] - 1s 107ms/step - loss: 0.0371
# Epoch 4/25
# 7/7 [==============================] - 1s 106ms/step - loss: 0.0266
# Epoch 5/25
# 7/7 [==============================] - 1s 109ms/step - loss: 0.0180
# Epoch 6/25
# 7/7 [==============================] - 1s 110ms/step - loss: 0.0130
# Epoch 7/25
# 7/7 [==============================] - 1s 107ms/step - loss: 0.0119
# Epoch 8/25
# 7/7 [==============================] - 1s 108ms/step - loss: 0.0103
# Epoch 9/25
# 7/7 [==============================] - 1s 105ms/step - loss: 0.0093
# Epoch 10/25
# 7/7 [==============================] - 1s 104ms/step - loss: 0.0083
# Epoch 11/25
# 7/7 [==============================] - 1s 103ms/step - loss: 0.0085
# Epoch 12/25
# 7/7 [==============================] - 1s 107ms/step - loss: 0.0078
# Epoch 13/25
# 7/7 [==============================] - 1s 109ms/step - loss: 0.0068
# Epoch 14/25
# 7/7 [==============================] - 1s 106ms/step - loss: 0.0076
# Epoch 15/25
# 7/7 [==============================] - 1s 107ms/step - loss: 0.0064
# Epoch 16/25
# 7/7 [==============================] - 1s 104ms/step - loss: 0.0064
# Epoch 17/25
# 7/7 [==============================] - 1s 104ms/step - loss: 0.0068
# Epoch 18/25
# 7/7 [==============================] - 1s 106ms/step - loss: 0.0065
# Epoch 19/25
# 7/7 [==============================] - 1s 107ms/step - loss: 0.0061
# Epoch 20/25
# 7/7 [==============================] - 1s 106ms/step - loss: 0.0056
# Epoch 21/25
# 7/7 [==============================] - 1s 106ms/step - loss: 0.0058
# Epoch 22/25
# 7/7 [==============================] - 1s 106ms/step - loss: 0.0054
# Epoch 23/25
# 7/7 [==============================] - 1s 107ms/step - loss: 0.0051
# Epoch 24/25
# 7/7 [==============================] - 1s 105ms/step - loss: 0.0053
# Epoch 25/25
# 7/7 [==============================] - 1s 103ms/step - loss: 0.0045
# Starting this param
# {'layers': 5, 'epochs': 50, 'batches': 100, 'units': [113, 113, 113, 113, 113], 'dropouts': [0.2, 0.5, 0.5, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_5_50_100'}
# Epoch 1/50
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0992
# Epoch 2/50
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0357
# Epoch 3/50
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0149
# Epoch 4/50
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0111
# Epoch 5/50
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0085
# Epoch 6/50
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0074
# Epoch 7/50
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0084
# Epoch 8/50
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0075
# Epoch 9/50
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0073
# Epoch 10/50
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0072
# Epoch 11/50
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0059
# Epoch 12/50
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0059
# Epoch 13/50
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0056
# Epoch 14/50
# 14/14 [==============================] - 1s 70ms/step - loss: 0.0066
# Epoch 15/50
# 14/14 [==============================] - 1s 70ms/step - loss: 0.0060
# Epoch 16/50
# 14/14 [==============================] - 1s 70ms/step - loss: 0.0049
# Epoch 17/50
# 14/14 [==============================] - 1s 70ms/step - loss: 0.0048
# Epoch 18/50
# 14/14 [==============================] - 1s 70ms/step - loss: 0.0045
# Epoch 19/50
# 14/14 [==============================] - 1s 70ms/step - loss: 0.0049
# Epoch 20/50
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0052
# Epoch 21/50
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0053
# Epoch 22/50
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0044
# Epoch 23/50
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0047
# Epoch 24/50
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0042
# Epoch 25/50
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0044
# Epoch 26/50
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0040
# Epoch 27/50
# 14/14 [==============================] - 1s 70ms/step - loss: 0.0042
# Epoch 28/50
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0040
# Epoch 29/50
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0045
# Epoch 30/50
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0039
# Epoch 31/50
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0042
# Epoch 32/50
# 14/14 [==============================] - 1s 75ms/step - loss: 0.0042
# Epoch 33/50
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0052
# Epoch 34/50
# 14/14 [==============================] - 1s 75ms/step - loss: 0.0043
# Epoch 35/50
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0043
# Epoch 36/50
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0040
# Epoch 37/50
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0040
# Epoch 38/50
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0041
# Epoch 39/50
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0037
# Epoch 40/50
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0038
# Epoch 41/50
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0035
# Epoch 42/50
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0036
# Epoch 43/50
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0038
# Epoch 44/50
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0035
# Epoch 45/50
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0031
# Epoch 46/50
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0034
# Epoch 47/50
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0039
# Epoch 48/50
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0036
# Epoch 49/50
# 14/14 [==============================] - 1s 70ms/step - loss: 0.0038
# Epoch 50/50
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0039
# Starting this param
# {'layers': 5, 'epochs': 50, 'batches': 200, 'units': [113, 113, 113, 113, 113], 'dropouts': [0.2, 0.5, 0.5, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_5_50_200'}
# Epoch 1/50
# 7/7 [==============================] - 1s 105ms/step - loss: 0.1534
# Epoch 2/50
# 7/7 [==============================] - 1s 106ms/step - loss: 0.0445
# Epoch 3/50
# 7/7 [==============================] - 1s 106ms/step - loss: 0.0393
# Epoch 4/50
# 7/7 [==============================] - 1s 105ms/step - loss: 0.0246
# Epoch 5/50
# 7/7 [==============================] - 1s 107ms/step - loss: 0.0160
# Epoch 6/50
# 7/7 [==============================] - 1s 110ms/step - loss: 0.0141
# Epoch 7/50
# 7/7 [==============================] - 1s 106ms/step - loss: 0.0105
# Epoch 8/50
# 7/7 [==============================] - 1s 109ms/step - loss: 0.0090
# Epoch 9/50
# 7/7 [==============================] - 1s 116ms/step - loss: 0.0102
# Epoch 10/50
# 7/7 [==============================] - 1s 109ms/step - loss: 0.0082
# Epoch 11/50
# 7/7 [==============================] - 1s 114ms/step - loss: 0.0082
# Epoch 12/50
# 7/7 [==============================] - 1s 113ms/step - loss: 0.0081
# Epoch 13/50
# 7/7 [==============================] - 1s 111ms/step - loss: 0.0071
# Epoch 14/50
# 7/7 [==============================] - 1s 115ms/step - loss: 0.0073
# Epoch 15/50
# 7/7 [==============================] - 1s 107ms/step - loss: 0.0072
# Epoch 16/50
# 7/7 [==============================] - 1s 108ms/step - loss: 0.0069
# Epoch 17/50
# 7/7 [==============================] - 1s 107ms/step - loss: 0.0061
# Epoch 18/50
# 7/7 [==============================] - 1s 106ms/step - loss: 0.0057
# Epoch 19/50
# 7/7 [==============================] - 1s 107ms/step - loss: 0.0057
# Epoch 20/50
# 7/7 [==============================] - 1s 106ms/step - loss: 0.0052
# Epoch 21/50
# 7/7 [==============================] - 1s 107ms/step - loss: 0.0054
# Epoch 22/50
# 7/7 [==============================] - 1s 108ms/step - loss: 0.0054
# Epoch 23/50
# 7/7 [==============================] - 1s 112ms/step - loss: 0.0055
# Epoch 24/50
# 7/7 [==============================] - 1s 108ms/step - loss: 0.0049
# Epoch 25/50
# 7/7 [==============================] - 1s 112ms/step - loss: 0.0049
# Epoch 26/50
# 7/7 [==============================] - 1s 106ms/step - loss: 0.0050
# Epoch 27/50
# 7/7 [==============================] - 1s 107ms/step - loss: 0.0050
# Epoch 28/50
# 7/7 [==============================] - 1s 108ms/step - loss: 0.0050
# Epoch 29/50
# 7/7 [==============================] - 1s 106ms/step - loss: 0.0050
# Epoch 30/50
# 7/7 [==============================] - 1s 111ms/step - loss: 0.0051
# Epoch 31/50
# 7/7 [==============================] - 1s 112ms/step - loss: 0.0045
# Epoch 32/50
# 7/7 [==============================] - 1s 108ms/step - loss: 0.0045
# Epoch 33/50
# 7/7 [==============================] - 1s 108ms/step - loss: 0.0046
# Epoch 34/50
# 7/7 [==============================] - 1s 106ms/step - loss: 0.0047
# Epoch 35/50
# 7/7 [==============================] - 1s 109ms/step - loss: 0.0043
# Epoch 36/50
# 7/7 [==============================] - 1s 107ms/step - loss: 0.0051
# Epoch 37/50
# 7/7 [==============================] - 1s 106ms/step - loss: 0.0045
# Epoch 38/50
# 7/7 [==============================] - 1s 109ms/step - loss: 0.0043
# Epoch 39/50
# 7/7 [==============================] - 1s 107ms/step - loss: 0.0049
# Epoch 40/50
# 7/7 [==============================] - 1s 106ms/step - loss: 0.0044
# Epoch 41/50
# 7/7 [==============================] - 1s 107ms/step - loss: 0.0041
# Epoch 42/50
# 7/7 [==============================] - 1s 109ms/step - loss: 0.0039
# Epoch 43/50
# 7/7 [==============================] - 1s 107ms/step - loss: 0.0044
# Epoch 44/50
# 7/7 [==============================] - 1s 108ms/step - loss: 0.0038
# Epoch 45/50
# 7/7 [==============================] - 1s 107ms/step - loss: 0.0040
# Epoch 46/50
# 7/7 [==============================] - 1s 108ms/step - loss: 0.0044
# Epoch 47/50
# 7/7 [==============================] - 1s 108ms/step - loss: 0.0044
# Epoch 48/50
# 7/7 [==============================] - 1s 111ms/step - loss: 0.0041
# Epoch 49/50
# 7/7 [==============================] - 1s 109ms/step - loss: 0.0041
# Epoch 50/50
# 7/7 [==============================] - 1s 108ms/step - loss: 0.0037

# %% [markdown]
# ###Testing

# %% [markdown]
# Testing Loop

# %%
def save_test_image(yTest, y_pred, file_name):
  plt.plot(yTest, color='black', label='Actual')
  plt.plot(y_pred, color='red', label='Predict')
  plt.title('Testing')
  plt.xlabel('time [days]')
  plt.ylabel('price')
  plt.legend(loc='best')
  plt.savefig(fname = (file_name +'_test_img.jpg'))
  plt.close()
  return None

# %%
def save_train_image(yTrain, y_pred, file_name):
  plt.plot(yTrain, color='black', label='Actual')
  plt.plot(y_pred, color='red', label='Predict')
  plt.title('Training')
  plt.xlabel('time [days]')
  plt.ylabel('price')
  plt.legend(loc='best')
  plt.savefig(fname = (file_name+'_train_img.jpg'))
  plt.close()
  return None

# %%
time_training
# Out:
# [14.038393,
#  11.864215999999999,
#  30.102958,
#  25.776771000000004,
#  57.05496699999999,
#  46.89958999999999,
#  23.368696,
#  20.474156000000022,
#  50.69746199999997,
#  42.448622,
#  95.7602,
#  80.21918600000004]

# %%
time_evaluating = []
header = ['file_name: layers, epoch, batch', 'mse_scaled', 'mse_unscaled', 'overall_time']
results = []
yTest_scaled = yTest * upscale_value
yTrain_scaled = yTrain * upscale_value

for i in range(len(networks)):
  t0 = time.clock()
  nnet = networks[i]
  file_name = params[i]['file_name']
  #test images and result
  yPred_test = nnet.predict(xTest)
  yPred_test_scaled = yPred_test * upscale_value
  save_test_image(yTest_scaled, yPred_test_scaled, file_name)

  mse_unscaled = calc_mse(yTest, yPred_test)
  mse_scaled = calc_mse(yTest_scaled, yPred_test_scaled)

  #training images
  yPred_train = nnet.predict(xTrain)
  yPred_train_scaled = yPred_train * upscale_value
  save_train_image(yTrain_scaled, yPred_train_scaled, file_name)
  t1 = time.clock()

  time_evaluating = t1-t0
  overall_time = time_training[i] + time_evaluating
  stats = [file_name, round(mse_scaled,3), round(mse_unscaled,3), round(overall_time, 3)]
  results.append(stats)

# %%
results_df = pd.DataFrame(data = results, columns= header)
results_df.to_csv('LSTM_' + csv_name+'_results.csv')

# %%
# !zip -r /content/file.zip /content/

from google.colab import files
files.download("/content/file.zip")
# Out:
#   adding: content/ (stored 0%)
#   adding: content/.config/ (stored 0%)
#   adding: content/.config/.last_survey_prompt.yaml (stored 0%)
#   adding: content/.config/config_sentinel (stored 0%)
#   adding: content/.config/.last_update_check.json (deflated 22%)
#   adding: content/.config/active_config (stored 0%)
#   adding: content/.config/.last_opt_in_prompt.yaml (stored 0%)
#   adding: content/.config/gce (stored 0%)
#   adding: content/.config/logs/ (stored 0%)
#   adding: content/.config/logs/2020.12.02/ (stored 0%)
#   adding: content/.config/logs/2020.12.02/22.03.37.873126.log (deflated 91%)
#   adding: content/.config/logs/2020.12.02/22.04.13.854338.log (deflated 87%)
#   adding: content/.config/logs/2020.12.02/22.04.21.823807.log (deflated 54%)
#   adding: content/.config/logs/2020.12.02/22.03.59.234441.log (deflated 53%)
#   adding: content/.config/logs/2020.12.02/22.04.37.441505.log (deflated 54%)
#   adding: content/.config/logs/2020.12.02/22.04.38.150307.log (deflated 54%)
#   adding: content/.config/configurations/ (stored 0%)
#   adding: content/.config/configurations/config_default (deflated 15%)
#   adding: content/.config/.metricsUUID (stored 0%)
#   adding: content/Stats_MSFT_CSD_5_25_100_train_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_5_25_200.csv (deflated 49%)
#   adding: content/Stats_MSFT_CSD_5_50_200_train_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_5_10_100_train_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_5_10_100_test_img.jpg (deflated 12%)
#   adding: content/Stats_MSFT_CSD_5_50_100_train_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_3_10_100.csv (deflated 42%)
#   adding: content/Stats_MSFT_CSD_5_10_100.csv (deflated 42%)
#   adding: content/Stats_MSFT_CSD_5_25_200_train_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_3_25_200_train_img.jpg (deflated 14%)
#   adding: content/Stats_MSFT_CSD_5_50_100.csv (deflated 52%)
#   adding: content/LSTM_MSFT_CSD_results.csv (deflated 53%)
#   adding: content/Stats_MSFT_CSD_5_50_200.csv (deflated 52%)
#   adding: content/Stats_MSFT_CSD_5_10_200.csv (deflated 41%)
#   adding: content/Stats_MSFT_CSD_3_10_200_train_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_5_10_200_train_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_5_50_100_test_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_5_25_200_test_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_5_50_200_test_img.jpg (deflated 12%)
#   adding: content/Stats_MSFT_CSD_3_25_200_test_img.jpg (deflated 12%)
#   adding: content/Stats_MSFT_CSD_3_50_200.csv (deflated 53%)
#   adding: content/Stats_MSFT_CSD_3_10_100_test_img.jpg (deflated 11%)
#   adding: content/Stats_MSFT_CSD_5_25_100.csv (deflated 50%)
#   adding: content/Stats_MSFT_CSD_3_25_100_test_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_3_50_200_train_img.jpg (deflated 14%)
#   adding: content/Stats_MSFT_CSD_3_25_100.csv (deflated 50%)
#   adding: content/Stats_MSFT_CSD_3_50_200_test_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_3_50_100_train_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_3_10_200.csv (deflated 41%)
#   adding: content/Stats_MSFT_CSD_3_50_100.csv (deflated 53%)
#   adding: content/Stats_MSFT_CSD_3_25_200.csv (deflated 50%)
#   adding: content/Stats_MSFT_CSD_3_25_100_train_img.jpg (deflated 14%)
#   adding: content/Stats_MSFT_CSD_3_10_200_test_img.jpg (deflated 11%)
#   adding: content/Stats_MSFT_CSD_3_50_100_test_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_5_10_200_test_img.jpg (deflated 12%)
#   adding: content/Stats_MSFT_CSD_5_25_100_test_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_3_10_100_train_img.jpg (deflated 14%)
#   adding: content/sample_data/ (stored 0%)
#   adding: content/sample_data/anscombe.json (deflated 83%)
#   adding: content/sample_data/README.md (deflated 42%)
#   adding: content/sample_data/california_housing_test.csv (deflated 76%)
#   adding: content/sample_data/mnist_test.csv (deflated 88%)
#   adding: content/sample_data/mnist_train_small.csv (deflated 88%)
#   adding: content/sample_data/california_housing_train.csv (deflated 79%)
