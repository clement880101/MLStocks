# %% [markdown]
# #Setup

# %%
pip install keras-adabound
# Out:
# Collecting keras-adabound
#   Downloading https://files.pythonhosted.org/packages/bf/74/85de8379eba8e0f819ef9b62ff32d24a3f624758800e12bd9572e3afb546/keras-adabound-0.6.0.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from keras-adabound) (1.18.5)
# Requirement already satisfied: Keras in /usr/local/lib/python3.6/dist-packages (from keras-adabound) (2.4.3)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.6/dist-packages (from keras-adabound) (2.7.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras->keras-adabound) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from Keras->keras-adabound) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras->keras-adabound) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->Keras->keras-adabound) (1.15.0)
# Building wheels for collected packages: keras-adabound
#   Building wheel for keras-adabound (setup.py) ... done
#   Created wheel for keras-adabound: filename=keras_adabound-0.6.0-cp36-none-any.whl size=6608 sha256=06faf8766d5dbc0a8c52c95b210165e1ba380f7def5fcb4e373e9f73fd6cc1e5
#   Stored in directory: /root/.cache/pip/wheels/f1/81/9c/04af926d62bddd280c97af1704a9baaef511664b56865958e8
# Successfully built keras-adabound
# Installing collected packages: keras-adabound
# Successfully installed keras-adabound-0.6.0

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
#from keras_adabound import AdaBound
from tensorflow.keras import Sequential
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU
from sklearn.metrics import mean_squared_error as calc_mse
import time

# %%
csv = pd.read_csv('https://raw.githubusercontent.com/clement880101/MLStocks/master/Combined_Stock_Data_MSFT.csv', date_parser= True)
csv.columns
# Out:
# Index(['date', 'Msft_open', 'Msft_high', 'Msft_low', 'Msft_close',
#        'Msft_adjusted_close', 'Msft_volume', 'Msft_dividend',
#        'Msft_split_coefficent', 'Msft_Real Middle Band',
#        ...
#        'Amzn_ADX', 'Amzn_SMA', 'SPY_open', 'SPY_high', 'SPY_low', 'SPY_close',
#        'SPY_adjusted_close', 'SPY_volume', 'SPY_dividend',
#        'SPY_split_coefficent'],
#       dtype='object', length=114)

# %% [markdown]
# # Recurrent LSTM Neural Network

# %% [markdown]
# ###help functions

# %%
#helper functions
def to_dataframe(csv):
    # returns dataframe
    df = pd.read_csv(csv, date_parser=True)
    return df

def reverse_order(df):
    # reverse order of data so earliest day is day 0
    reversed_df = df[::-1].reset_index(drop=True)
    return reversed_df

def remove_dates(df):
  #stores dates in a dictionary
  dates = {}
  for i in range(df.shape[0]):
    date = df.iloc[i]['date']
    dates[date] = i

  df = df.drop(['date'],axis=1)

  return dates, df

def scale_data(df, target_column):
    # scale data
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(df)

    # save this value to convert stock prediction to nominal data
    upscale_value = 1 / scaler.scale_[target_column]
    return scaled_data, scaler, upscale_value

def split_data(df, date_value):
  df_before = df[df['date'] < date_value].copy()
  df_after = df[df['date'] >= date_value].copy()
  return df_before, df_after

def create_xy(data, scope, target_column):
  x = []
  y = []
  for i in range(scope, data.shape[0]):
    # the xTest will have an array of the last x "scope" days of data
    # yTest will be the the opening value of the next day
    x.append(data[i-scope:i])
    y.append(data[i,target_column])
  
  #the length of x is the data length - scope 
  #in each x there is a batch size of x "scope" points
  return np.array(x), np.array(y)
#recurrent neural network

class Rnn:
    # set values for Rnn object
    def __init__(self, rows_size, columns_size):
        self.rows = rows_size
        self.columns = columns_size
        self.model = None
        self.logs = None


    # train function for Rnn class
    def structure(self, layers, units_for_layers, dropouts_for_layers):
        #initilize Sequential rnn
        self.model = Sequential()
        # add first layer and define input shape
        self.model.add(GRU(units_for_layers[0], activation = 'relu', return_sequences = True, input_shape = (self.rows, self.columns)))
        self.model.add(Dropout(dropouts_for_layers[0]))
        # for adding additional layers
        if layers > 2:
            for i in range(1,layers):

                return_setting = True
                #dont need to return values upstream on last layer
                if i == layers - 1: return_setting = False

                self.model.add(GRU(units_for_layers[i], activation = 'relu', return_sequences = return_setting))
                self.model.add(Dropout(dropouts_for_layers[i]))


        #final endpoint for rnn layers
        self.model.add(Dense(units = 1))
        return None

    def summary(self):
        return self.model.summary()
      
    def history(self):
      return self.model.history

    def train(self, xTrain, yTrain, epochs, batch_size, optimizer, file_name, ada_low_lr = None, ada_high_lr = None):
        #compiles model that was created
        if optimizer != 'adaboost':
            self.model.compile(optimizer=optimizer, loss = 'mean_squared_error')
        else:
            self.model.compile(optimizer= AdaBound(lr=ada_low_lr, final_lr=ada_high_lr), loss = 'mean_squared_error')

        #create log for getting stats
        CSV_logger = CSVLogger(file_name + '.csv',separator=',',append=False)
        #fit model to data
        self.model.fit(xTrain, yTrain, epochs=epochs, batch_size=batch_size, callbacks=[CSV_logger])
        self.logs = CSV_logger
        return None

    def predict(self, input_data):
        y_hat = self.model.predict(input_data)
        return y_hat

# %%
def create_file_name(array):
  string = 'Stats'
  for item in array:
    string = string + '_' + str(item)
  return string

# %% [markdown]
# ###main

# %%
#arrange df and split by date
df = reverse_order(csv)
training_data, test_data = split_data(df, '2018-01-01')

#store date labels and drop columns 
dates_train, training_data = remove_dates(training_data)
dates_test, test_data = remove_dates(test_data)

target_column = 5 #this is MSFT adjusted column
#scale_data on training data and get scaler with value
training_data, scaler, upscale_value = scale_data(training_data, target_column-1)
test_data = scaler.transform(test_data)

# %%
#create xTrain,yTrain.. and xTest,yTest
#each x in xTrain will be an array of x days
xTrain, yTrain = create_xy(training_data, 5, target_column-1)
xTest, yTest = create_xy(test_data, 5, target_column-1)

# %% [markdown]
# ###Params loop

# %%
#batch dimensions
row_size = xTrain.shape[1]
column_size = xTrain.shape[2]
# params to test
layers = [3,5]
epochs = [10, 25, 50]
batches = [100, 200]
optimizer = 'adam'

# %%
params = []
csv_name = 'MSFT_CSD'

for l in layers:
  units = []
  dropouts = []
  for i in range(l):
    units.append(column_size)
    if i == 0:
      dropouts.append(0.2)
    else: 
      dropouts.append(0.5)

  for e in epochs:
    for b in batches:
      file_name = create_file_name([csv_name,l,e,b])
      params.append({'layers': l,'epochs': e,'batches': b, 'units': units, 'dropouts': dropouts, 'optimizer': optimizer, 'file_name': file_name})

# %%
params[0]['file_name']
# Out:
# 'Stats_MSFT_CSD_3_10_100'

# %% [markdown]
# ### Create evaluation loop

# %%
#track_time_to_train
time_training = []
networks = []
for param in params:
  t0 = time.clock()
  #Steps for rnn:
  #1. initialize, #2. structure, #train, #summary, #predict
  print('Starting this param'), print(param)
  nnet = Rnn(row_size,column_size)
  nnet.structure(param['layers'], param['units'], param['dropouts'])
  nnet.train(xTrain, yTrain, param['epochs'],param['batches'],param['optimizer'],param['file_name'])
  networks.append(nnet)
  t1 = time.clock()
  time_training.append(t1-t0)
# Out:
# Starting this param
# {'layers': 3, 'epochs': 10, 'batches': 100, 'units': [113, 113, 113], 'dropouts': [0.2, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_3_10_100'}
# Epoch 1/10
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0486
# Epoch 2/10
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0159
# Epoch 3/10
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0122
# Epoch 4/10
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0095
# Epoch 5/10
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0080
# Epoch 6/10
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0076
# Epoch 7/10
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0070
# Epoch 8/10
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0062
# Epoch 9/10
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0065
# Epoch 10/10
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0060
# Starting this param
# {'layers': 3, 'epochs': 10, 'batches': 200, 'units': [113, 113, 113], 'dropouts': [0.2, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_3_10_200'}
# Epoch 1/10
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0661
# Epoch 2/10
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0205
# Epoch 3/10
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0157
# Epoch 4/10
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0124
# Epoch 5/10
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0104
# Epoch 6/10
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0091
# Epoch 7/10
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0088
# Epoch 8/10
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0078
# Epoch 9/10
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0073
# Epoch 10/10
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0065
# Starting this param
# {'layers': 3, 'epochs': 25, 'batches': 100, 'units': [113, 113, 113], 'dropouts': [0.2, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_3_25_100'}
# Epoch 1/25
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0339
# Epoch 2/25
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0154
# Epoch 3/25
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0115
# Epoch 4/25
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0101
# Epoch 5/25
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0081
# Epoch 6/25
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0074
# Epoch 7/25
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0080
# Epoch 8/25
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0063
# Epoch 9/25
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0060
# Epoch 10/25
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0050
# Epoch 11/25
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0056
# Epoch 12/25
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0047
# Epoch 13/25
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0056
# Epoch 14/25
# 14/14 [==============================] - 0s 36ms/step - loss: 0.0046
# Epoch 15/25
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0042
# Epoch 16/25
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0042
# Epoch 17/25
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0043
# Epoch 18/25
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0048
# Epoch 19/25
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0041
# Epoch 20/25
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0036
# Epoch 21/25
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0040
# Epoch 22/25
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0038
# Epoch 23/25
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0040
# Epoch 24/25
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0037
# Epoch 25/25
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0038
# Starting this param
# {'layers': 3, 'epochs': 25, 'batches': 200, 'units': [113, 113, 113], 'dropouts': [0.2, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_3_25_200'}
# Epoch 1/25
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0819
# Epoch 2/25
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0316
# Epoch 3/25
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0184
# Epoch 4/25
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0137
# Epoch 5/25
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0116
# Epoch 6/25
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0099
# Epoch 7/25
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0093
# Epoch 8/25
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0091
# Epoch 9/25
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0076
# Epoch 10/25
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0074
# Epoch 11/25
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0074
# Epoch 12/25
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0070
# Epoch 13/25
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0074
# Epoch 14/25
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0062
# Epoch 15/25
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0058
# Epoch 16/25
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0056
# Epoch 17/25
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0063
# Epoch 18/25
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0055
# Epoch 19/25
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0056
# Epoch 20/25
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0057
# Epoch 21/25
# 7/7 [==============================] - 0s 59ms/step - loss: 0.0061
# Epoch 22/25
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0060
# Epoch 23/25
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0053
# Epoch 24/25
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0052
# Epoch 25/25
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0045
# Starting this param
# {'layers': 3, 'epochs': 50, 'batches': 100, 'units': [113, 113, 113], 'dropouts': [0.2, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_3_50_100'}
# Epoch 1/50
# 14/14 [==============================] - 0s 36ms/step - loss: 0.0559
# Epoch 2/50
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0158
# Epoch 3/50
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0106
# Epoch 4/50
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0095
# Epoch 5/50
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0085
# Epoch 6/50
# 14/14 [==============================] - 1s 38ms/step - loss: 0.0080
# Epoch 7/50
# 14/14 [==============================] - 1s 38ms/step - loss: 0.0072
# Epoch 8/50
# 14/14 [==============================] - 1s 38ms/step - loss: 0.0066
# Epoch 9/50
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0057
# Epoch 10/50
# 14/14 [==============================] - 1s 39ms/step - loss: 0.0068
# Epoch 11/50
# 14/14 [==============================] - 1s 38ms/step - loss: 0.0068
# Epoch 12/50
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0059
# Epoch 13/50
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0053
# Epoch 14/50
# 14/14 [==============================] - 0s 36ms/step - loss: 0.0054
# Epoch 15/50
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0050
# Epoch 16/50
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0050
# Epoch 17/50
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0042
# Epoch 18/50
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0044
# Epoch 19/50
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0045
# Epoch 20/50
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0045
# Epoch 21/50
# 14/14 [==============================] - 0s 36ms/step - loss: 0.0045
# Epoch 22/50
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0047
# Epoch 23/50
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0047
# Epoch 24/50
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0046
# Epoch 25/50
# 14/14 [==============================] - 0s 36ms/step - loss: 0.0042
# Epoch 26/50
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0041
# Epoch 27/50
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0042
# Epoch 28/50
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0044
# Epoch 29/50
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0036
# Epoch 30/50
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0039
# Epoch 31/50
# 14/14 [==============================] - 0s 36ms/step - loss: 0.0040
# Epoch 32/50
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0039
# Epoch 33/50
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0035
# Epoch 34/50
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0036
# Epoch 35/50
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0036
# Epoch 36/50
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0032
# Epoch 37/50
# 14/14 [==============================] - 0s 36ms/step - loss: 0.0040
# Epoch 38/50
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0039
# Epoch 39/50
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0034
# Epoch 40/50
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0036
# Epoch 41/50
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0032
# Epoch 42/50
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0035
# Epoch 43/50
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0033
# Epoch 44/50
# 14/14 [==============================] - 0s 36ms/step - loss: 0.0034
# Epoch 45/50
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0029
# Epoch 46/50
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0034
# Epoch 47/50
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0028
# Epoch 48/50
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0028
# Epoch 49/50
# 14/14 [==============================] - 0s 36ms/step - loss: 0.0031
# Epoch 50/50
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0031
# Starting this param
# {'layers': 3, 'epochs': 50, 'batches': 200, 'units': [113, 113, 113], 'dropouts': [0.2, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_3_50_200'}
# Epoch 1/50
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0825
# Epoch 2/50
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0321
# Epoch 3/50
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0162
# Epoch 4/50
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0136
# Epoch 5/50
# 7/7 [==============================] - 0s 59ms/step - loss: 0.0117
# Epoch 6/50
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0098
# Epoch 7/50
# 7/7 [==============================] - 0s 59ms/step - loss: 0.0081
# Epoch 8/50
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0088
# Epoch 9/50
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0075
# Epoch 10/50
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0075
# Epoch 11/50
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0066
# Epoch 12/50
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0068
# Epoch 13/50
# 7/7 [==============================] - 0s 59ms/step - loss: 0.0072
# Epoch 14/50
# 7/7 [==============================] - 0s 60ms/step - loss: 0.0062
# Epoch 15/50
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0065
# Epoch 16/50
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0054
# Epoch 17/50
# 7/7 [==============================] - 0s 60ms/step - loss: 0.0060
# Epoch 18/50
# 7/7 [==============================] - 0s 59ms/step - loss: 0.0051
# Epoch 19/50
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0049
# Epoch 20/50
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0053
# Epoch 21/50
# 7/7 [==============================] - 0s 60ms/step - loss: 0.0047
# Epoch 22/50
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0051
# Epoch 23/50
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0047
# Epoch 24/50
# 7/7 [==============================] - 0s 59ms/step - loss: 0.0049
# Epoch 25/50
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0052
# Epoch 26/50
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0046
# Epoch 27/50
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0045
# Epoch 28/50
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0044
# Epoch 29/50
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0039
# Epoch 30/50
# 7/7 [==============================] - 0s 60ms/step - loss: 0.0042
# Epoch 31/50
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0045
# Epoch 32/50
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0040
# Epoch 33/50
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0036
# Epoch 34/50
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0041
# Epoch 35/50
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0045
# Epoch 36/50
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0039
# Epoch 37/50
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0046
# Epoch 38/50
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0044
# Epoch 39/50
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0041
# Epoch 40/50
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0039
# Epoch 41/50
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0040
# Epoch 42/50
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0041
# Epoch 43/50
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0039
# Epoch 44/50
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0040
# Epoch 45/50
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0038
# Epoch 46/50
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0040
# Epoch 47/50
# 7/7 [==============================] - 0s 59ms/step - loss: 0.0035
# Epoch 48/50
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0038
# Epoch 49/50
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0034
# Epoch 50/50
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0034
# Starting this param
# {'layers': 5, 'epochs': 10, 'batches': 100, 'units': [113, 113, 113, 113, 113], 'dropouts': [0.2, 0.5, 0.5, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_5_10_100'}
# Epoch 1/10
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0808
# Epoch 2/10
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0266
# Epoch 3/10
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0168
# Epoch 4/10
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0133
# Epoch 5/10
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0106
# Epoch 6/10
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0101
# Epoch 7/10
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0097
# Epoch 8/10
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0084
# Epoch 9/10
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0083
# Epoch 10/10
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0085
# Starting this param
# {'layers': 5, 'epochs': 10, 'batches': 200, 'units': [113, 113, 113, 113, 113], 'dropouts': [0.2, 0.5, 0.5, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_5_10_200'}
# Epoch 1/10
# 7/7 [==============================] - 1s 97ms/step - loss: 0.1047
# Epoch 2/10
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0383
# Epoch 3/10
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0207
# Epoch 4/10
# 7/7 [==============================] - 1s 96ms/step - loss: 0.0151
# Epoch 5/10
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0123
# Epoch 6/10
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0117
# Epoch 7/10
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0102
# Epoch 8/10
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0090
# Epoch 9/10
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0094
# Epoch 10/10
# 7/7 [==============================] - 1s 92ms/step - loss: 0.0090
# Starting this param
# {'layers': 5, 'epochs': 25, 'batches': 100, 'units': [113, 113, 113, 113, 113], 'dropouts': [0.2, 0.5, 0.5, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_5_25_100'}
# Epoch 1/25
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0652
# Epoch 2/25
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0178
# Epoch 3/25
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0134
# Epoch 4/25
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0107
# Epoch 5/25
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0096
# Epoch 6/25
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0089
# Epoch 7/25
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0073
# Epoch 8/25
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0068
# Epoch 9/25
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0063
# Epoch 10/25
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0062
# Epoch 11/25
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0058
# Epoch 12/25
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0059
# Epoch 13/25
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0056
# Epoch 14/25
# 14/14 [==============================] - 1s 63ms/step - loss: 0.0052
# Epoch 15/25
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0058
# Epoch 16/25
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0058
# Epoch 17/25
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0063
# Epoch 18/25
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0053
# Epoch 19/25
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0047
# Epoch 20/25
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0048
# Epoch 21/25
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0045
# Epoch 22/25
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0053
# Epoch 23/25
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0041
# Epoch 24/25
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0058
# Epoch 25/25
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0051
# Starting this param
# {'layers': 5, 'epochs': 25, 'batches': 200, 'units': [113, 113, 113, 113, 113], 'dropouts': [0.2, 0.5, 0.5, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_5_25_200'}
# Epoch 1/25
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0877
# Epoch 2/25
# 7/7 [==============================] - 1s 96ms/step - loss: 0.0286
# Epoch 3/25
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0163
# Epoch 4/25
# 7/7 [==============================] - 1s 93ms/step - loss: 0.0130
# Epoch 5/25
# 7/7 [==============================] - 1s 92ms/step - loss: 0.0103
# Epoch 6/25
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0102
# Epoch 7/25
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0093
# Epoch 8/25
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0083
# Epoch 9/25
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0079
# Epoch 10/25
# 7/7 [==============================] - 1s 93ms/step - loss: 0.0077
# Epoch 11/25
# 7/7 [==============================] - 1s 99ms/step - loss: 0.0073
# Epoch 12/25
# 7/7 [==============================] - 1s 92ms/step - loss: 0.0072
# Epoch 13/25
# 7/7 [==============================] - 1s 93ms/step - loss: 0.0075
# Epoch 14/25
# 7/7 [==============================] - 1s 93ms/step - loss: 0.0070
# Epoch 15/25
# 7/7 [==============================] - 1s 99ms/step - loss: 0.0066
# Epoch 16/25
# 7/7 [==============================] - 1s 99ms/step - loss: 0.0064
# Epoch 17/25
# 7/7 [==============================] - 1s 100ms/step - loss: 0.0061
# Epoch 18/25
# 7/7 [==============================] - 1s 98ms/step - loss: 0.0061
# Epoch 19/25
# 7/7 [==============================] - 1s 100ms/step - loss: 0.0065
# Epoch 20/25
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0064
# Epoch 21/25
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0061
# Epoch 22/25
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0054
# Epoch 23/25
# 7/7 [==============================] - 1s 98ms/step - loss: 0.0064
# Epoch 24/25
# 7/7 [==============================] - 1s 98ms/step - loss: 0.0063
# Epoch 25/25
# 7/7 [==============================] - 1s 98ms/step - loss: 0.0059
# Starting this param
# {'layers': 5, 'epochs': 50, 'batches': 100, 'units': [113, 113, 113, 113, 113], 'dropouts': [0.2, 0.5, 0.5, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_5_50_100'}
# Epoch 1/50
# 14/14 [==============================] - 1s 64ms/step - loss: 0.0822
# Epoch 2/50
# 14/14 [==============================] - 1s 63ms/step - loss: 0.0254
# Epoch 3/50
# 14/14 [==============================] - 1s 63ms/step - loss: 0.0150
# Epoch 4/50
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0105
# Epoch 5/50
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0110
# Epoch 6/50
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0085
# Epoch 7/50
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0091
# Epoch 8/50
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0087
# Epoch 9/50
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0084
# Epoch 10/50
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0081
# Epoch 11/50
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0077
# Epoch 12/50
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0076
# Epoch 13/50
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0079
# Epoch 14/50
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0073
# Epoch 15/50
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0068
# Epoch 16/50
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0059
# Epoch 17/50
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0060
# Epoch 18/50
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0056
# Epoch 19/50
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0062
# Epoch 20/50
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0053
# Epoch 21/50
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0057
# Epoch 22/50
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0050
# Epoch 23/50
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0049
# Epoch 24/50
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0057
# Epoch 25/50
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0050
# Epoch 26/50
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0051
# Epoch 27/50
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0046
# Epoch 28/50
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0048
# Epoch 29/50
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0049
# Epoch 30/50
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0051
# Epoch 31/50
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0050
# Epoch 32/50
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0048
# Epoch 33/50
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0049
# Epoch 34/50
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0048
# Epoch 35/50
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0048
# Epoch 36/50
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0046
# Epoch 37/50
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0044
# Epoch 38/50
# 14/14 [==============================] - 1s 64ms/step - loss: 0.0047
# Epoch 39/50
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0042
# Epoch 40/50
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0040
# Epoch 41/50
# 14/14 [==============================] - 1s 65ms/step - loss: 0.0040
# Epoch 42/50
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0044
# Epoch 43/50
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0039
# Epoch 44/50
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0043
# Epoch 45/50
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0043
# Epoch 46/50
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0042
# Epoch 47/50
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0035
# Epoch 48/50
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0037
# Epoch 49/50
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0036
# Epoch 50/50
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0037
# Starting this param
# {'layers': 5, 'epochs': 50, 'batches': 200, 'units': [113, 113, 113, 113, 113], 'dropouts': [0.2, 0.5, 0.5, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_CSD_5_50_200'}
# Epoch 1/50
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0953
# Epoch 2/50
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0346
# Epoch 3/50
# 7/7 [==============================] - 1s 96ms/step - loss: 0.0202
# Epoch 4/50
# 7/7 [==============================] - 1s 96ms/step - loss: 0.0175
# Epoch 5/50
# 7/7 [==============================] - 1s 96ms/step - loss: 0.0153
# Epoch 6/50
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0126
# Epoch 7/50
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0116
# Epoch 8/50
# 7/7 [==============================] - 1s 96ms/step - loss: 0.0123
# Epoch 9/50
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0100
# Epoch 10/50
# 7/7 [==============================] - 1s 98ms/step - loss: 0.0089
# Epoch 11/50
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0088
# Epoch 12/50
# 7/7 [==============================] - 1s 96ms/step - loss: 0.0092
# Epoch 13/50
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0081
# Epoch 14/50
# 7/7 [==============================] - 1s 96ms/step - loss: 0.0085
# Epoch 15/50
# 7/7 [==============================] - 1s 93ms/step - loss: 0.0076
# Epoch 16/50
# 7/7 [==============================] - 1s 98ms/step - loss: 0.0076
# Epoch 17/50
# 7/7 [==============================] - 1s 93ms/step - loss: 0.0072
# Epoch 18/50
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0074
# Epoch 19/50
# 7/7 [==============================] - 1s 98ms/step - loss: 0.0074
# Epoch 20/50
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0068
# Epoch 21/50
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0070
# Epoch 22/50
# 7/7 [==============================] - 1s 99ms/step - loss: 0.0072
# Epoch 23/50
# 7/7 [==============================] - 1s 99ms/step - loss: 0.0064
# Epoch 24/50
# 7/7 [==============================] - 1s 102ms/step - loss: 0.0063
# Epoch 25/50
# 7/7 [==============================] - 1s 98ms/step - loss: 0.0060
# Epoch 26/50
# 7/7 [==============================] - 1s 99ms/step - loss: 0.0062
# Epoch 27/50
# 7/7 [==============================] - 1s 93ms/step - loss: 0.0065
# Epoch 28/50
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0065
# Epoch 29/50
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0069
# Epoch 30/50
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0059
# Epoch 31/50
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0052
# Epoch 32/50
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0057
# Epoch 33/50
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0055
# Epoch 34/50
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0053
# Epoch 35/50
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0059
# Epoch 36/50
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0052
# Epoch 37/50
# 7/7 [==============================] - 1s 93ms/step - loss: 0.0050
# Epoch 38/50
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0057
# Epoch 39/50
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0049
# Epoch 40/50
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0048
# Epoch 41/50
# 7/7 [==============================] - 1s 98ms/step - loss: 0.0051
# Epoch 42/50
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0049
# Epoch 43/50
# 7/7 [==============================] - 1s 102ms/step - loss: 0.0048
# Epoch 44/50
# 7/7 [==============================] - 1s 99ms/step - loss: 0.0048
# Epoch 45/50
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0046
# Epoch 46/50
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0045
# Epoch 47/50
# 7/7 [==============================] - 1s 99ms/step - loss: 0.0042
# Epoch 48/50
# 7/7 [==============================] - 1s 98ms/step - loss: 0.0045
# Epoch 49/50
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0048
# Epoch 50/50
# 7/7 [==============================] - 1s 100ms/step - loss: 0.0042

# %% [markdown]
# ###Testing

# %% [markdown]
# Testing Loop

# %%
def save_test_image(yTest, y_pred, file_name):
  plt.plot(yTest, color='black', label='Actual')
  plt.plot(y_pred, color='red', label='Predict')
  plt.title('Testing')
  plt.xlabel('time [days]')
  plt.ylabel('price')
  plt.legend(loc='best')
  plt.savefig(fname = (file_name +'_test_img.jpg'))
  plt.close()
  return None

# %%
def save_train_image(yTrain, y_pred, file_name):
  plt.plot(yTrain, color='black', label='Actual')
  plt.plot(y_pred, color='red', label='Predict')
  plt.title('Training')
  plt.xlabel('time [days]')
  plt.ylabel('price')
  plt.legend(loc='best')
  plt.savefig(fname = (file_name+'_train_img.jpg'))
  plt.close()
  return None

# %%
time_training
# Out:
# [12.689476999999998,
#  11.337488999999998,
#  26.287920000000003,
#  22.952023000000004,
#  49.131112,
#  42.03391199999999,
#  21.024074000000013,
#  19.01872399999999,
#  43.68935000000002,
#  38.921538,
#  81.98759899999999,
#  72.74683900000002]

# %%
time_evaluating = []
header = ['file_name: layers, epoch, batch', 'mse_scaled', 'mse_unscaled', 'overall_time']
results = []
yTest_scaled = yTest * upscale_value
yTrain_scaled = yTrain * upscale_value

for i in range(len(networks)):
  t0 = time.clock()
  nnet = networks[i]
  file_name = params[i]['file_name']
  #test images and result
  yPred_test = nnet.predict(xTest)
  yPred_test_scaled = yPred_test * upscale_value
  save_test_image(yTest_scaled, yPred_test_scaled, file_name)

  mse_unscaled = calc_mse(yTest, yPred_test)
  mse_scaled = calc_mse(yTest_scaled, yPred_test_scaled)

  #training images
  yPred_train = nnet.predict(xTrain)
  yPred_train_scaled = yPred_train * upscale_value
  save_test_image(yTrain_scaled, yPred_train_scaled, file_name)
  t1 = time.clock()

  time_evaluating = t1-t0
  overall_time = time_training[i] + time_evaluating
  stats = [file_name, mse_scaled, mse_unscaled, overall_time]
  results.append(stats)

# %%
results_df = pd.DataFrame(data = results, columns= header)
results_df.to_csv(csv_name+'_results.csv')

# %%
# !zip -r /content/file.zip /content/

from google.colab import files
files.download("/content/file.zip")
# Out:
#   adding: content/ (stored 0%)
#   adding: content/.config/ (stored 0%)
#   adding: content/.config/configurations/ (stored 0%)
#   adding: content/.config/configurations/config_default (deflated 15%)
#   adding: content/.config/logs/ (stored 0%)
#   adding: content/.config/logs/2020.12.02/ (stored 0%)
#   adding: content/.config/logs/2020.12.02/22.04.13.854338.log (deflated 87%)
#   adding: content/.config/logs/2020.12.02/22.04.38.150307.log (deflated 54%)
#   adding: content/.config/logs/2020.12.02/22.04.21.823807.log (deflated 54%)
#   adding: content/.config/logs/2020.12.02/22.03.59.234441.log (deflated 53%)
#   adding: content/.config/logs/2020.12.02/22.03.37.873126.log (deflated 91%)
#   adding: content/.config/logs/2020.12.02/22.04.37.441505.log (deflated 54%)
#   adding: content/.config/active_config (stored 0%)
#   adding: content/.config/config_sentinel (stored 0%)
#   adding: content/.config/.last_update_check.json (deflated 22%)
#   adding: content/.config/.last_survey_prompt.yaml (stored 0%)
#   adding: content/.config/.last_opt_in_prompt.yaml (stored 0%)
#   adding: content/.config/gce (stored 0%)
#   adding: content/.config/.metricsUUID (stored 0%)
#   adding: content/Stats_MSFT_CSD_3_25_100_test_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_5_25_100_test_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_5_10_200.csv (deflated 40%)
#   adding: content/Stats_MSFT_CSD_5_10_100.csv (deflated 41%)
#   adding: content/Stats_MSFT_CSD_3_10_200_test_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_5_50_100_test_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_3_25_200_test_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_3_25_100.csv (deflated 50%)
#   adding: content/Stats_MSFT_CSD_5_50_200.csv (deflated 52%)
#   adding: content/MSFT_CSD_results.csv (deflated 52%)
#   adding: content/Stats_MSFT_CSD_3_50_200.csv (deflated 53%)
#   adding: content/Stats_MSFT_CSD_3_10_200.csv (deflated 41%)
#   adding: content/Stats_MSFT_CSD_3_25_200.csv (deflated 49%)
#   adding: content/Stats_MSFT_CSD_5_50_100.csv (deflated 53%)
#   adding: content/Stats_MSFT_CSD_5_10_200_test_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_5_50_200_test_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_3_50_100.csv (deflated 53%)
#   adding: content/Stats_MSFT_CSD_5_10_100_test_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_5_25_200.csv (deflated 50%)
#   adding: content/Stats_MSFT_CSD_5_25_100.csv (deflated 50%)
#   adding: content/Stats_MSFT_CSD_3_50_100_test_img.jpg (deflated 14%)
#   adding: content/Stats_MSFT_CSD_3_50_200_test_img.jpg (deflated 14%)
#   adding: content/Stats_MSFT_CSD_3_10_100_test_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_5_25_200_test_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_CSD_3_10_100.csv (deflated 41%)
#   adding: content/sample_data/ (stored 0%)
#   adding: content/sample_data/anscombe.json (deflated 83%)
#   adding: content/sample_data/README.md (deflated 42%)
#   adding: content/sample_data/california_housing_test.csv (deflated 76%)
#   adding: content/sample_data/mnist_train_small.csv (deflated 88%)
#   adding: content/sample_data/california_housing_train.csv (deflated 79%)
#   adding: content/sample_data/mnist_test.csv (deflated 88%)
