# %% [markdown]
# #Setup

# %%
pip install keras-adabound
# Out:
# Collecting keras-adabound
#   Downloading https://files.pythonhosted.org/packages/bf/74/85de8379eba8e0f819ef9b62ff32d24a3f624758800e12bd9572e3afb546/keras-adabound-0.6.0.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from keras-adabound) (1.18.5)
# Requirement already satisfied: Keras in /usr/local/lib/python3.6/dist-packages (from keras-adabound) (2.4.3)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.6/dist-packages (from keras-adabound) (2.7.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras->keras-adabound) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras->keras-adabound) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from Keras->keras-adabound) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->Keras->keras-adabound) (1.15.0)
# Building wheels for collected packages: keras-adabound
#   Building wheel for keras-adabound (setup.py) ... done
#   Created wheel for keras-adabound: filename=keras_adabound-0.6.0-cp36-none-any.whl size=6608 sha256=86d303a66b73167cd2c2a4a811c4b45bb68340a508b44836bdfddc8198215c9f
#   Stored in directory: /root/.cache/pip/wheels/f1/81/9c/04af926d62bddd280c97af1704a9baaef511664b56865958e8
# Successfully built keras-adabound
# Installing collected packages: keras-adabound
# Successfully installed keras-adabound-0.6.0

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
#from keras_adabound import AdaBound
from tensorflow.keras import Sequential
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU
from sklearn.metrics import mean_squared_error as calc_mse
import time

# %%
csv = pd.read_csv('https://raw.githubusercontent.com/clement880101/MLStocks/master/Msft.csv', date_parser= True)
csv.columns
# Out:
# Index(['date', 'Msft_open', 'Msft_high', 'Msft_low', 'Msft_close',
#        'Msft_adjusted_close', 'Msft_volume', 'Msft_dividend',
#        'Msft_split_coefficent', 'Msft_Real Middle Band',
#        'Msft_Real Upper Band', 'Msft_Real Lower Band', 'Msft_MACD',
#        'Msft_MACD_Hist', 'Msft_MACD_Signal', 'Msft_RSI', 'Msft_CCI',
#        'Msft_Aroon Down', 'Msft_Aroon Up', 'Msft_Chaikin A/D', 'Msft_ADX',
#        'Msft_SMA', 'SPY_open', 'SPY_high', 'SPY_low', 'SPY_close',
#        'SPY_adjusted_close', 'SPY_volume', 'SPY_dividend',
#        'SPY_split_coefficent'],
#       dtype='object')

# %% [markdown]
# # Recurrent LSTM Neural Network

# %% [markdown]
# ###help functions

# %%
#helper functions
def to_dataframe(csv):
    # returns dataframe
    df = pd.read_csv(csv, date_parser=True)
    return df

def reverse_order(df):
    # reverse order of data so earliest day is day 0
    reversed_df = df[::-1].reset_index(drop=True)
    return reversed_df

def remove_dates(df):
  #stores dates in a dictionary
  dates = {}
  for i in range(df.shape[0]):
    date = df.iloc[i]['date']
    dates[date] = i

  df = df.drop(['date'],axis=1)

  return dates, df

def scale_data(df, target_column):
    # scale data
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(df)

    # save this value to convert stock prediction to nominal data
    upscale_value = 1 / scaler.scale_[target_column]
    return scaled_data, scaler, upscale_value

def split_data(df, date_value):
  df_before = df[df['date'] < date_value].copy()
  df_after = df[df['date'] >= date_value].copy()
  return df_before, df_after

def create_xy(data, scope, target_column):
  x = []
  y = []
  for i in range(scope, data.shape[0]):
    # the xTest will have an array of the last x "scope" days of data
    # yTest will be the the opening value of the next day
    x.append(data[i-scope:i])
    y.append(data[i,target_column])
  
  #the length of x is the data length - scope 
  #in each x there is a batch size of x "scope" points
  return np.array(x), np.array(y)
#recurrent neural network

class Rnn:
    # set values for Rnn object
    def __init__(self, rows_size, columns_size):
        self.rows = rows_size
        self.columns = columns_size
        self.model = None
        self.logs = None


    # train function for Rnn class
    def structure(self, layers, units_for_layers, dropouts_for_layers):
        #initilize Sequential rnn
        self.model = Sequential()
        # add first layer and define input shape
        self.model.add(GRU(units_for_layers[0], activation = 'relu', return_sequences = True, input_shape = (self.rows, self.columns)))
        self.model.add(Dropout(dropouts_for_layers[0]))
        # for adding additional layers
        if layers > 2:
            for i in range(1,layers):

                return_setting = True
                #dont need to return values upstream on last layer
                if i == layers - 1: return_setting = False

                self.model.add(GRU(units_for_layers[i], activation = 'relu', return_sequences = return_setting))
                self.model.add(Dropout(dropouts_for_layers[i]))


        #final endpoint for rnn layers
        self.model.add(Dense(units = 1))
        return None

    def summary(self):
        return self.model.summary()
      
    def history(self):
      return self.model.history

    def train(self, xTrain, yTrain, epochs, batch_size, optimizer, file_name, ada_low_lr = None, ada_high_lr = None):
        #compiles model that was created
        if optimizer != 'adaboost':
            self.model.compile(optimizer=optimizer, loss = 'mean_squared_error')
        else:
            self.model.compile(optimizer= AdaBound(lr=ada_low_lr, final_lr=ada_high_lr), loss = 'mean_squared_error')

        #create log for getting stats
        CSV_logger = CSVLogger(file_name + '.csv',separator=',',append=False)
        #fit model to data
        self.model.fit(xTrain, yTrain, epochs=epochs, batch_size=batch_size, callbacks=[CSV_logger])
        self.logs = CSV_logger
        return None

    def predict(self, input_data):
        y_hat = self.model.predict(input_data)
        return y_hat

# %%
def create_file_name(array):
  string = 'Stats'
  for item in array:
    string = string + '_' + str(item)
  return string

# %% [markdown]
# ###main

# %%
#arrange df and split by date
df = reverse_order(csv)
training_data, test_data = split_data(df, '2018-01-01')

#store date labels and drop columns 
dates_train, training_data = remove_dates(training_data)
dates_test, test_data = remove_dates(test_data)

target_column = 5 #this is MSFT adjusted column
#scale_data on training data and get scaler with value
training_data, scaler, upscale_value = scale_data(training_data, target_column-1)
test_data = scaler.transform(test_data)

# %%
#create xTrain,yTrain.. and xTest,yTest
#each x in xTrain will be an array of x days
xTrain, yTrain = create_xy(training_data, 5, target_column-1)
xTest, yTest = create_xy(test_data, 5, target_column-1)

# %% [markdown]
# ###Params loop

# %%
#batch dimensions
row_size = xTrain.shape[1]
column_size = xTrain.shape[2]
# params to test
layers = [3,5]
epochs = [10, 25, 50]
batches = [100, 200]
optimizer = 'adam'

# %%
params = []
csv_name = 'MSFT'

for l in layers:
  units = []
  dropouts = []
  for i in range(l):
    units.append(column_size)
    if i == 0:
      dropouts.append(0.2)
    else: 
      dropouts.append(0.5)

  for e in epochs:
    for b in batches:
      file_name = create_file_name([csv_name,l,e,b])
      params.append({'layers': l,'epochs': e,'batches': b, 'units': units, 'dropouts': dropouts, 'optimizer': optimizer, 'file_name': file_name})

# %%
params[0]['file_name']
# Out:
# 'Stats_MSFT_3_10_100'

# %% [markdown]
# ### Create evaluation loop

# %%
#track_time_to_train
time_training = []
networks = []
for param in params:
  t0 = time.clock()
  #Steps for rnn:
  #1. initialize, #2. structure, #train, #summary, #predict
  print('Starting this param'), print(param)
  nnet = Rnn(row_size,column_size)
  nnet.structure(param['layers'], param['units'], param['dropouts'])
  nnet.train(xTrain, yTrain, param['epochs'],param['batches'],param['optimizer'],param['file_name'])
  networks.append(nnet)
  t1 = time.clock()
  time_training.append(t1-t0)
# Out:
# Starting this param
# {'layers': 3, 'epochs': 10, 'batches': 100, 'units': [29, 29, 29], 'dropouts': [0.2, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_3_10_100'}
# Epoch 1/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0486
# Epoch 2/10
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0142
# Epoch 3/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0106
# Epoch 4/10
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0084
# Epoch 5/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0074
# Epoch 6/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0079
# Epoch 7/10
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0070
# Epoch 8/10
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0065
# Epoch 9/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0057
# Epoch 10/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0058
# Starting this param
# {'layers': 3, 'epochs': 10, 'batches': 200, 'units': [29, 29, 29], 'dropouts': [0.2, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_3_10_200'}
# Epoch 1/10
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0649
# Epoch 2/10
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0261
# Epoch 3/10
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0163
# Epoch 4/10
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0125
# Epoch 5/10
# 23/23 [==============================] - 0s 14ms/step - loss: 0.0109
# Epoch 6/10
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0098
# Epoch 7/10
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0091
# Epoch 8/10
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0081
# Epoch 9/10
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0080
# Epoch 10/10
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0077
# Starting this param
# {'layers': 3, 'epochs': 25, 'batches': 100, 'units': [29, 29, 29], 'dropouts': [0.2, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_3_25_100'}
# Epoch 1/25
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0302
# Epoch 2/25
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0113
# Epoch 3/25
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0085
# Epoch 4/25
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0060
# Epoch 5/25
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0058
# Epoch 6/25
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0048
# Epoch 7/25
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0044
# Epoch 8/25
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0044
# Epoch 9/25
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0043
# Epoch 10/25
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0039
# Epoch 11/25
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0041
# Epoch 12/25
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0040
# Epoch 13/25
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0037
# Epoch 14/25
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0035
# Epoch 15/25
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0033
# Epoch 16/25
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0035
# Epoch 17/25
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0036
# Epoch 18/25
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0034
# Epoch 19/25
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0035
# Epoch 20/25
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0033
# Epoch 21/25
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0032
# Epoch 22/25
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0030
# Epoch 23/25
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0031
# Epoch 24/25
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0029
# Epoch 25/25
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0030
# Starting this param
# {'layers': 3, 'epochs': 25, 'batches': 200, 'units': [29, 29, 29], 'dropouts': [0.2, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_3_25_200'}
# Epoch 1/25
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0350
# Epoch 2/25
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0152
# Epoch 3/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0111
# Epoch 4/25
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0094
# Epoch 5/25
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0083
# Epoch 6/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0080
# Epoch 7/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0068
# Epoch 8/25
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0068
# Epoch 9/25
# 23/23 [==============================] - 0s 14ms/step - loss: 0.0060
# Epoch 10/25
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0058
# Epoch 11/25
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0055
# Epoch 12/25
# 23/23 [==============================] - 0s 14ms/step - loss: 0.0054
# Epoch 13/25
# 23/23 [==============================] - 0s 14ms/step - loss: 0.0050
# Epoch 14/25
# 23/23 [==============================] - 0s 15ms/step - loss: 0.0046
# Epoch 15/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0046
# Epoch 16/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0042
# Epoch 17/25
# 23/23 [==============================] - 0s 14ms/step - loss: 0.0044
# Epoch 18/25
# 23/23 [==============================] - 0s 14ms/step - loss: 0.0044
# Epoch 19/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0041
# Epoch 20/25
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0040
# Epoch 21/25
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0040
# Epoch 22/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0040
# Epoch 23/25
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0043
# Epoch 24/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0040
# Epoch 25/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0041
# Starting this param
# {'layers': 3, 'epochs': 50, 'batches': 100, 'units': [29, 29, 29], 'dropouts': [0.2, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_3_50_100'}
# Epoch 1/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0212
# Epoch 2/50
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0089
# Epoch 3/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0075
# Epoch 4/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0066
# Epoch 5/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0055
# Epoch 6/50
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0051
# Epoch 7/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0044
# Epoch 8/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0046
# Epoch 9/50
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0043
# Epoch 10/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0041
# Epoch 11/50
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0041
# Epoch 12/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0042
# Epoch 13/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0035
# Epoch 14/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0036
# Epoch 15/50
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0036
# Epoch 16/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0037
# Epoch 17/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0035
# Epoch 18/50
# 46/46 [==============================] - 1s 12ms/step - loss: 0.0034
# Epoch 19/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0034
# Epoch 20/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0035
# Epoch 21/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0035
# Epoch 22/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0034
# Epoch 23/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0032
# Epoch 24/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0035
# Epoch 25/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0032
# Epoch 26/50
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0034
# Epoch 27/50
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0030
# Epoch 28/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0032
# Epoch 29/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0029
# Epoch 30/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0032
# Epoch 31/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0031
# Epoch 32/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0030
# Epoch 33/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0030
# Epoch 34/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0030
# Epoch 35/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0029
# Epoch 36/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0033
# Epoch 37/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0028
# Epoch 38/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0032
# Epoch 39/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0030
# Epoch 40/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0029
# Epoch 41/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0028
# Epoch 42/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0030
# Epoch 43/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0031
# Epoch 44/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0031
# Epoch 45/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0028
# Epoch 46/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0031
# Epoch 47/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0027
# Epoch 48/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0026
# Epoch 49/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0028
# Epoch 50/50
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0029
# Starting this param
# {'layers': 3, 'epochs': 50, 'batches': 200, 'units': [29, 29, 29], 'dropouts': [0.2, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_3_50_200'}
# Epoch 1/50
# 23/23 [==============================] - 0s 14ms/step - loss: 0.0634
# Epoch 2/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0274
# Epoch 3/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0136
# Epoch 4/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0110
# Epoch 5/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0104
# Epoch 6/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0093
# Epoch 7/50
# 23/23 [==============================] - 0s 14ms/step - loss: 0.0089
# Epoch 8/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0081
# Epoch 9/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0077
# Epoch 10/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0076
# Epoch 11/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0078
# Epoch 12/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0074
# Epoch 13/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0066
# Epoch 14/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0062
# Epoch 15/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0061
# Epoch 16/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0058
# Epoch 17/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0059
# Epoch 18/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0062
# Epoch 19/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0053
# Epoch 20/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0050
# Epoch 21/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0056
# Epoch 22/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0051
# Epoch 23/50
# 23/23 [==============================] - 0s 14ms/step - loss: 0.0052
# Epoch 24/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0050
# Epoch 25/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0050
# Epoch 26/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0046
# Epoch 27/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0049
# Epoch 28/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0048
# Epoch 29/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0047
# Epoch 30/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0041
# Epoch 31/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0046
# Epoch 32/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0042
# Epoch 33/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0041
# Epoch 34/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0042
# Epoch 35/50
# 23/23 [==============================] - 0s 15ms/step - loss: 0.0041
# Epoch 36/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0040
# Epoch 37/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0042
# Epoch 38/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0041
# Epoch 39/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0041
# Epoch 40/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0041
# Epoch 41/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0041
# Epoch 42/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0039
# Epoch 43/50
# 23/23 [==============================] - 0s 14ms/step - loss: 0.0040
# Epoch 44/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0040
# Epoch 45/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0040
# Epoch 46/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0036
# Epoch 47/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0041
# Epoch 48/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0036
# Epoch 49/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0040
# Epoch 50/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0038
# Starting this param
# {'layers': 5, 'epochs': 10, 'batches': 100, 'units': [29, 29, 29, 29, 29], 'dropouts': [0.2, 0.5, 0.5, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_5_10_100'}
# Epoch 1/10
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0470
# Epoch 2/10
# 46/46 [==============================] - 1s 15ms/step - loss: 0.0185
# Epoch 3/10
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0133
# Epoch 4/10
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0116
# Epoch 5/10
# 46/46 [==============================] - 1s 15ms/step - loss: 0.0098
# Epoch 6/10
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0085
# Epoch 7/10
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0081
# Epoch 8/10
# 46/46 [==============================] - 1s 15ms/step - loss: 0.0085
# Epoch 9/10
# 46/46 [==============================] - 1s 15ms/step - loss: 0.0079
# Epoch 10/10
# 46/46 [==============================] - 1s 15ms/step - loss: 0.0068
# Starting this param
# {'layers': 5, 'epochs': 10, 'batches': 200, 'units': [29, 29, 29, 29, 29], 'dropouts': [0.2, 0.5, 0.5, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_5_10_200'}
# Epoch 1/10
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0498
# Epoch 2/10
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0216
# Epoch 3/10
# 23/23 [==============================] - 1s 23ms/step - loss: 0.0132
# Epoch 4/10
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0111
# Epoch 5/10
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0096
# Epoch 6/10
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0085
# Epoch 7/10
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0087
# Epoch 8/10
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0073
# Epoch 9/10
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0073
# Epoch 10/10
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0067
# Starting this param
# {'layers': 5, 'epochs': 25, 'batches': 100, 'units': [29, 29, 29, 29, 29], 'dropouts': [0.2, 0.5, 0.5, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_5_25_100'}
# Epoch 1/25
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0490
# Epoch 2/25
# 46/46 [==============================] - 1s 15ms/step - loss: 0.0185
# Epoch 3/25
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0133
# Epoch 4/25
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0115
# Epoch 5/25
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0097
# Epoch 6/25
# 46/46 [==============================] - 1s 17ms/step - loss: 0.0090
# Epoch 7/25
# 46/46 [==============================] - 1s 17ms/step - loss: 0.0082
# Epoch 8/25
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0078
# Epoch 9/25
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0069
# Epoch 10/25
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0071
# Epoch 11/25
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0064
# Epoch 12/25
# 46/46 [==============================] - 1s 17ms/step - loss: 0.0070
# Epoch 13/25
# 46/46 [==============================] - 1s 17ms/step - loss: 0.0071
# Epoch 14/25
# 46/46 [==============================] - 1s 17ms/step - loss: 0.0064
# Epoch 15/25
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0063
# Epoch 16/25
# 46/46 [==============================] - 1s 19ms/step - loss: 0.0055
# Epoch 17/25
# 46/46 [==============================] - 1s 17ms/step - loss: 0.0054
# Epoch 18/25
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0064
# Epoch 19/25
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0057
# Epoch 20/25
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0056
# Epoch 21/25
# 46/46 [==============================] - 1s 17ms/step - loss: 0.0059
# Epoch 22/25
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0059
# Epoch 23/25
# 46/46 [==============================] - 1s 17ms/step - loss: 0.0060
# Epoch 24/25
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0059
# Epoch 25/25
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0060
# Starting this param
# {'layers': 5, 'epochs': 25, 'batches': 200, 'units': [29, 29, 29, 29, 29], 'dropouts': [0.2, 0.5, 0.5, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_5_25_200'}
# Epoch 1/25
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0477
# Epoch 2/25
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0213
# Epoch 3/25
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0147
# Epoch 4/25
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0124
# Epoch 5/25
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0121
# Epoch 6/25
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0106
# Epoch 7/25
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0096
# Epoch 8/25
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0092
# Epoch 9/25
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0093
# Epoch 10/25
# 23/23 [==============================] - 1s 24ms/step - loss: 0.0081
# Epoch 11/25
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0085
# Epoch 12/25
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0072
# Epoch 13/25
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0075
# Epoch 14/25
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0069
# Epoch 15/25
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0065
# Epoch 16/25
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0065
# Epoch 17/25
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0063
# Epoch 18/25
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0058
# Epoch 19/25
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0062
# Epoch 20/25
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0062
# Epoch 21/25
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0056
# Epoch 22/25
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0059
# Epoch 23/25
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0057
# Epoch 24/25
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0056
# Epoch 25/25
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0054
# Starting this param
# {'layers': 5, 'epochs': 50, 'batches': 100, 'units': [29, 29, 29, 29, 29], 'dropouts': [0.2, 0.5, 0.5, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_5_50_100'}
# Epoch 1/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0331
# Epoch 2/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0120
# Epoch 3/50
# 46/46 [==============================] - 1s 15ms/step - loss: 0.0107
# Epoch 4/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0091
# Epoch 5/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0082
# Epoch 6/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0076
# Epoch 7/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0066
# Epoch 8/50
# 46/46 [==============================] - 1s 18ms/step - loss: 0.0065
# Epoch 9/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0056
# Epoch 10/50
# 46/46 [==============================] - 1s 17ms/step - loss: 0.0065
# Epoch 11/50
# 46/46 [==============================] - 1s 17ms/step - loss: 0.0056
# Epoch 12/50
# 46/46 [==============================] - 1s 18ms/step - loss: 0.0055
# Epoch 13/50
# 46/46 [==============================] - 1s 15ms/step - loss: 0.0050
# Epoch 14/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0049
# Epoch 15/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0051
# Epoch 16/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0047
# Epoch 17/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0048
# Epoch 18/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0045
# Epoch 19/50
# 46/46 [==============================] - 1s 18ms/step - loss: 0.0050
# Epoch 20/50
# 46/46 [==============================] - 1s 18ms/step - loss: 0.0047
# Epoch 21/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0045
# Epoch 22/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0044
# Epoch 23/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0045
# Epoch 24/50
# 46/46 [==============================] - 1s 17ms/step - loss: 0.0048
# Epoch 25/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0045
# Epoch 26/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0040
# Epoch 27/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0044
# Epoch 28/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0042
# Epoch 29/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0044
# Epoch 30/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0047
# Epoch 31/50
# 46/46 [==============================] - 1s 17ms/step - loss: 0.0040
# Epoch 32/50
# 46/46 [==============================] - 1s 17ms/step - loss: 0.0043
# Epoch 33/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0041
# Epoch 34/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0046
# Epoch 35/50
# 46/46 [==============================] - 1s 17ms/step - loss: 0.0042
# Epoch 36/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0040
# Epoch 37/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0041
# Epoch 38/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0043
# Epoch 39/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0040
# Epoch 40/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0039
# Epoch 41/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0040
# Epoch 42/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0041
# Epoch 43/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0040
# Epoch 44/50
# 46/46 [==============================] - 1s 17ms/step - loss: 0.0043
# Epoch 45/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0043
# Epoch 46/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0039
# Epoch 47/50
# 46/46 [==============================] - 1s 18ms/step - loss: 0.0040
# Epoch 48/50
# 46/46 [==============================] - 1s 15ms/step - loss: 0.0039
# Epoch 49/50
# 46/46 [==============================] - 1s 16ms/step - loss: 0.0038
# Epoch 50/50
# 46/46 [==============================] - 1s 17ms/step - loss: 0.0040
# Starting this param
# {'layers': 5, 'epochs': 50, 'batches': 200, 'units': [29, 29, 29, 29, 29], 'dropouts': [0.2, 0.5, 0.5, 0.5, 0.5], 'optimizer': 'adam', 'file_name': 'Stats_MSFT_5_50_200'}
# Epoch 1/50
# 23/23 [==============================] - 1s 22ms/step - loss: 0.0466
# Epoch 2/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0226
# Epoch 3/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0139
# Epoch 4/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0105
# Epoch 5/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0090
# Epoch 6/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0087
# Epoch 7/50
# 23/23 [==============================] - 1s 24ms/step - loss: 0.0075
# Epoch 8/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0076
# Epoch 9/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0067
# Epoch 10/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0065
# Epoch 11/50
# 23/23 [==============================] - 0s 22ms/step - loss: 0.0065
# Epoch 12/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0058
# Epoch 13/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0056
# Epoch 14/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0053
# Epoch 15/50
# 23/23 [==============================] - 1s 22ms/step - loss: 0.0049
# Epoch 16/50
# 23/23 [==============================] - 1s 22ms/step - loss: 0.0052
# Epoch 17/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0053
# Epoch 18/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0046
# Epoch 19/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0046
# Epoch 20/50
# 23/23 [==============================] - 1s 22ms/step - loss: 0.0047
# Epoch 21/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0045
# Epoch 22/50
# 23/23 [==============================] - 1s 22ms/step - loss: 0.0044
# Epoch 23/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0040
# Epoch 24/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0041
# Epoch 25/50
# 23/23 [==============================] - 1s 22ms/step - loss: 0.0043
# Epoch 26/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0043
# Epoch 27/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0045
# Epoch 28/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0045
# Epoch 29/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0040
# Epoch 30/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0037
# Epoch 31/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0042
# Epoch 32/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0040
# Epoch 33/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0041
# Epoch 34/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0041
# Epoch 35/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.0042
# Epoch 36/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0039
# Epoch 37/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0037
# Epoch 38/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0043
# Epoch 39/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0038
# Epoch 40/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0037
# Epoch 41/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0039
# Epoch 42/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0039
# Epoch 43/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0037
# Epoch 44/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0037
# Epoch 45/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0036
# Epoch 46/50
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0034
# Epoch 47/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0038
# Epoch 48/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0038
# Epoch 49/50
# 23/23 [==============================] - 1s 22ms/step - loss: 0.0036
# Epoch 50/50
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0037

# %% [markdown]
# ###Testing

# %% [markdown]
# Testing Loop

# %%
def save_test_image(yTest, y_pred, file_name):
  plt.plot(yTest, color='black', label='Actual')
  plt.plot(y_pred, color='red', label='Predict')
  plt.title('Testing')
  plt.xlabel('time [days]')
  plt.ylabel('price')
  plt.legend(loc='best')
  plt.savefig(fname = (file_name +'_test_img.jpg'))
  plt.close()
  return None

# %%
def save_train_image(yTrain, y_pred, file_name):
  plt.plot(yTrain, color='black', label='Actual')
  plt.plot(y_pred, color='red', label='Predict')
  plt.title('Training')
  plt.xlabel('time [days]')
  plt.ylabel('price')
  plt.legend(loc='best')
  plt.savefig(fname = (file_name+'_train_img.jpg'))
  plt.close()
  return None

# %%
time_training
# Out:
# [10.936708000000001,
#  8.309940999999998,
#  21.688443,
#  15.885004000000002,
#  40.037859999999995,
#  27.73062999999999,
#  17.494707000000005,
#  13.495456000000019,
#  36.49700200000001,
#  25.379065999999995,
#  66.41104099999998,
#  45.74076199999996]

# %%
results_df = pd.DataFrame(data = results, columns= header)
results_df.to_csv(csv_name+'_results.csv')

# %%
# !zip -r /content/file.zip /content/

from google.colab import files
files.download("/content/file.zip")
# Out:
#   adding: content/ (stored 0%)
#   adding: content/.config/ (stored 0%)
#   adding: content/.config/configurations/ (stored 0%)
#   adding: content/.config/configurations/config_default (deflated 15%)
#   adding: content/.config/logs/ (stored 0%)
#   adding: content/.config/logs/2020.12.02/ (stored 0%)
#   adding: content/.config/logs/2020.12.02/22.04.13.854338.log (deflated 87%)
#   adding: content/.config/logs/2020.12.02/22.04.38.150307.log (deflated 54%)
#   adding: content/.config/logs/2020.12.02/22.04.21.823807.log (deflated 54%)
#   adding: content/.config/logs/2020.12.02/22.03.59.234441.log (deflated 53%)
#   adding: content/.config/logs/2020.12.02/22.03.37.873126.log (deflated 91%)
#   adding: content/.config/logs/2020.12.02/22.04.37.441505.log (deflated 54%)
#   adding: content/.config/active_config (stored 0%)
#   adding: content/.config/config_sentinel (stored 0%)
#   adding: content/.config/.last_update_check.json (deflated 22%)
#   adding: content/.config/.last_survey_prompt.yaml (stored 0%)
#   adding: content/.config/.last_opt_in_prompt.yaml (stored 0%)
#   adding: content/.config/gce (stored 0%)
#   adding: content/.config/.metricsUUID (stored 0%)
#   adding: content/Stats_MSFT_5_25_200.csv (deflated 50%)
#   adding: content/Stats_MSFT_5_10_200.csv (deflated 41%)
#   adding: content/Stats_MSFT_5_50_200_test_img.jpg (deflated 14%)
#   adding: content/Stats_MSFT_3_10_100_test_img.jpg (deflated 14%)
#   adding: content/Stats_MSFT_5_10_100.csv (deflated 41%)
#   adding: content/Stats_MSFT_3_25_100_test_img.jpg (deflated 14%)
#   adding: content/Stats_MSFT_5_10_200_test_img.jpg (deflated 14%)
#   adding: content/Stats_MSFT_3_50_200_test_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_5_10_100_test_img.jpg (deflated 14%)
#   adding: content/Stats_MSFT_3_10_200_test_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_5_50_200.csv (deflated 52%)
#   adding: content/MSFT_results.csv (deflated 51%)
#   adding: content/Stats_MSFT_3_10_200.csv (deflated 42%)
#   adding: content/Stats_MSFT_3_25_100.csv (deflated 51%)
#   adding: content/Stats_MSFT_5_25_200_test_img.jpg (deflated 14%)
#   adding: content/Stats_MSFT_3_50_200.csv (deflated 52%)
#   adding: content/Stats_MSFT_5_50_100_test_img.jpg (deflated 14%)
#   adding: content/Stats_MSFT_3_50_100_test_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_5_50_100.csv (deflated 53%)
#   adding: content/Stats_MSFT_3_50_100.csv (deflated 53%)
#   adding: content/Stats_MSFT_3_10_100.csv (deflated 42%)
#   adding: content/Stats_MSFT_5_25_100.csv (deflated 50%)
#   adding: content/Stats_MSFT_3_25_200.csv (deflated 50%)
#   adding: content/Stats_MSFT_3_25_200_test_img.jpg (deflated 13%)
#   adding: content/Stats_MSFT_5_25_100_test_img.jpg (deflated 14%)
#   adding: content/sample_data/ (stored 0%)
#   adding: content/sample_data/anscombe.json (deflated 83%)
#   adding: content/sample_data/README.md (deflated 42%)
#   adding: content/sample_data/california_housing_test.csv (deflated 76%)
#   adding: content/sample_data/mnist_train_small.csv (deflated 88%)
#   adding: content/sample_data/california_housing_train.csv (deflated 79%)
#   adding: content/sample_data/mnist_test.csv (deflated 88%)
